# %%
import pandas as pd

# %%
pd.read_parquet("cache/AAPL_1d.parquet").head()
# Out:
#                        Date        open        high         low       close  \
# 0 2025-08-11 00:00:00-04:00  227.486400  229.123280  224.332408  226.747803
# 1 2025-08-12 00:00:00-04:00  227.576225  230.360926  226.638026  229.213104
# 2 2025-08-13 00:00:00-04:00  230.630428  234.552945  229.991631  232.886124
# 3 2025-08-14 00:00:00-04:00  233.614722  234.672703  230.410837  232.337158
# 4 2025-08-15 00:00:00-04:00  233.554833  233.834299  228.903695  231.149414
#
#      volume  dividends  stock_splits ticker
# 0  61806100       0.26           0.0   AAPL
# 1  55626200       0.00           0.0   AAPL
# 2  69878500       0.00           0.0   AAPL
# 3  51916300       0.00           0.0   AAPL
# 4  56038700       0.00           0.0   AAPL
